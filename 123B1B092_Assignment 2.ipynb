# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanishq-Btech/ML-assignments/blob/main/123B1B092_Assignment%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/Housing.csv')
df
# Out:
#           price     area bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000.0   7420.0        4        2.0      3.0      yes        no
# 1    12250000.0   8960.0        4        4.0      4.0      yes        no
# 2    12250000.0   9960.0        3        2.0      2.0      yes        no
# 3    12215000.0   7500.0        4        2.0      2.0      yes        no
# 4    11410000.0   7420.0        4        1.0      2.0      yes       yes
# ..          ...      ...      ...        ...      ...      ...       ...
# 544   1750000.0   3850.0        3        1.0      2.0      yes        no
# 545   7343000.0  11440.0        4        1.0      2.0      yes        no
# 546   7245000.0   9000.0        4        2.0      4.0      yes       yes
# 547   4900000.0   4646.0        3        1.0      2.0      yes       yes
# 548   4900000.0  12900.0        3        1.0      1.0      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['furnishingstatus']=le.fit_transform(df['furnishingstatus'])
df['mainroad']=le.fit_transform(df['mainroad'])
df['guestroom']=le.fit_transform(df['guestroom'])
df['basement']=le.fit_transform(df['basement'])
df['hotwaterheating']=le.fit_transform(df['hotwaterheating'])
df['airconditioning']=le.fit_transform(df['airconditioning'])
df['prefarea']=le.fit_transform(df['prefarea'])
df
# Out:
#           price     area bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000.0   7420.0        4        2.0      3.0         1          0
# 1    12250000.0   8960.0        4        4.0      4.0         1          0
# 2    12250000.0   9960.0        3        2.0      2.0         1          0
# 3    12215000.0   7500.0        4        2.0      2.0         1          0
# 4    11410000.0   7420.0        4        1.0      2.0         1          1
# ..          ...      ...      ...        ...      ...       ...        ...
# 544   1750000.0   3850.0        3        1.0      2.0         1          0
# 545   7343000.0  11440.0        4        1.0      2.0         1          0
# 546   7245000.0   9000.0        4        2.0      4.0         1          1
# 547   4900000.0   4646.0        3        1.0      2.0         1          1
# 548   4900000.0  12900.0        3        1.0      1.0         1          0
#
# ...

# %%
df.isnull().sum()
# Out:
# price               1
# area                3
# bedrooms            1
# bathrooms           1
# stories             2
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             1
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df['price']=df['price'].fillna(df['price'].mean())
df['area']=df['area'].fillna(df['area'].mean())
df['bedrooms']=df['bedrooms'].fillna(df['bedrooms'].mode()[0])
df['bathrooms']=df['bathrooms'].fillna(df['bathrooms'].mode()[0])

# %%
df['stories']=df['stories'].fillna(df['stories'].mode()[0])
df['parking']=df['parking'].fillna(df['parking'].mode()[0])

# %%
df
# Out:
#           price     area bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000.0   7420.0        4        2.0      3.0         1          0
# 1    12250000.0   8960.0        4        4.0      4.0         1          0
# 2    12250000.0   9960.0        3        2.0      2.0         1          0
# 3    12215000.0   7500.0        4        2.0      2.0         1          0
# 4    11410000.0   7420.0        4        1.0      2.0         1          1
# ..          ...      ...      ...        ...      ...       ...        ...
# 544   1750000.0   3850.0        3        1.0      2.0         1          0
# 545   7343000.0  11440.0        4        1.0      2.0         1          0
# 546   7245000.0   9000.0        4        2.0      4.0         1          1
# 547   4900000.0   4646.0        3        1.0      2.0         1          1
# 548   4900000.0  12900.0        3        1.0      1.0         1          0
#
# ...

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(4)

# %%
df.drop_duplicates(inplace=True)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(df.drop('price',axis=1),df['price'],test_size=0.2,random_state=42)

# %%
X_train.shape
# Out:
# (436, 12)

# %%
y_train.shape
# Out:
# (436,)

# %%
X_test.shape
# Out:
# (109, 12)

# %%
y_test.shape
# Out:
# (109,)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ 2.29260850e+02,  7.77246398e+04,  1.10459992e+06,  4.11024451e+05,
#         3.42713231e+05,  2.18321145e+05,  4.54817560e+05,  5.26483357e+05,
#         7.71721748e+05,  2.23879973e+05,  6.40909006e+05, -2.18224723e+05])

# %%
lr.intercept_
# Out:
# np.float64(321365.4234814523)

# %%
df
# Out:
#           price    area bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000.0  7420.0        4        2.0      3.0         1          0
# 1    12250000.0  8960.0        4        4.0      4.0         1          0
# 2    12250000.0  9960.0        3        2.0      2.0         1          0
# 3    12215000.0  7500.0        4        2.0      2.0         1          0
# 4    11410000.0  7420.0        4        1.0      2.0         1          1
# ..          ...     ...      ...        ...      ...       ...        ...
# 540   1820000.0  3000.0        2        1.0      1.0         1          0
# 541   1767150.0  2400.0        3        1.0      1.0         0          0
# 542   1750000.0  3620.0        2        1.0      1.0         1          0
# 543   1750000.0  2910.0        3        1.0      1.0         0          0
# 544   1750000.0  3850.0        3        1.0      2.0         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
import numpy as np
input_data = np.array([[6474, 4, 2, 5, 0, 1, 1, 0, 1, 4, 0, 1]])
prediction = lr.predict(input_data)
print(prediction)
# Out:
# [8502976.43304816]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
